# %%
listQueue = ["client1", "client2", "client3"]
print(listQueue)

# client = listQueue.pop(0)
# print(client)

while listQueue:
    client = listQueue.pop(0)
    print(listQueue)
# Out:
# ['client1', 'client2', 'client3']
# ['client2', 'client3']
# ['client3']
# []
