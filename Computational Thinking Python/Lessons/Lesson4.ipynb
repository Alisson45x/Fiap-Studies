# %%
# Exemplo 1

lista = []
ia = 0
for i in range(5):
    name = input("Name: ")
    lista.append(name)
    print(lista[ia])
    ia += 1
# Out:
# a
# b
# c
# d
# e

# %%
# Exemplo 2

soma = 0

for numero in range(1, 4):
    soma += numero
    print(soma)
# Out:
# 1
# 3
# 6

# %%
# Exemplo 3

for i in range(1, 6):
    if i == 4:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 5

# %%
# Exemplo 4

for i in range(1, 6):
    if i == 4:
        print(i)
# Out:
# 4
