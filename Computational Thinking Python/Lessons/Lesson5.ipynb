# %%
#Ex.1
opcao = input("Digite um numero: ")

match opcao:
    case "1":
        print("cadastrar")
    case "2" :
        print("Listar!")
    case _:
        print("Entrada invalida")
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/aliss/AppData/Roaming/uv/python/cpython-3.14.4-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#Ex.3

dados = ("produto", "arroz", 10)

match dados:
    case ("produto", nome, qtd):
        print(f"{nome} - {qtd}")
    case _:
        print("Entrada invalida!")

# %%
#Ex.4

lista = [1, 2 ,3]

match lista:
    case[1, 2, 3]:
        print("Lista correta")
    case _:
        print("Lista incorreta!")

# %%
#Ex.5
letra = "A"
status = "Ativo"
match (letra, status).upper:
    case ("A", "Ativo"):
        print("Acesso 1!")
    case ("B", "Inativo"):
        print("Aceeso 2!")

# %%
#Ex.6

numero = int(input("Entre com um número: "))
match numero:
    case _ if (numero %2 == 0):
        print("Par")
    case _:
        print("Impar")
# Out:
# Impar

# %%
#Ex.7

while True:
    mundial = input("Primeiro campeão mundial? ").lower()
    match mundial:
        case "corinthians":
            print("Correto")
        case _:
            print("Errado!!!!")
            break
# Out:
# Correto
# Errado!!!!

# %%
#Ex.8

def nome(parametros):
    
    "O que será feito com os parametros"
    return alguma

# %%
#Ex.9
def tabuada(a, b):

    for i in range(1, b + 1):
        print(f"{a} X {i} = {a * i}")
    
tabuada(6, 10)
# Out:
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# 6 X 10 = 60
