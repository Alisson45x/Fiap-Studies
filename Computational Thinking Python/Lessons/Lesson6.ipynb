# %%
def fatorial_rec(n):
    if n == 0:
        return 1
    return n * fatorial_rec(n - 1)
fatorial_rec(5)
# Out:
# 120

# %%
number = int(input("Digite qualquer bosta ai: "))
def fatorial_lit(n):
    resultado = 1
    count = n
    print(f"!{n}", end="")
    for i in range(1, n+1):
        resultado *= i
        count -= 1
        print(f".{count}", end="")
        
    return print(f" = {resultado}")
fatorial_lit(number)
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/aliss/AppData/Roaming/uv/python/cpython-3.14.4-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
lista_nomes= []
lista_idades= []
lista_sexo = []

for i in range(2):
    print(f"\nDados da {i + 1} Pessoa:")
    nome = input('digite o nome: ')
    lista_nomes.append(nome)
    idade = int(input("Digite a idade: "))
    lista_idades.append(idade)
    sexo = input("Digre M para Masculino e F para feminino: ")
    lista_sexo.append(sexo)

print(lista_nomes)
print(lista_idades)
print(lista_sexo)
# Out:
# Running cells with 'Python 3.14.4' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/aliss/AppData/Roaming/uv/python/cpython-3.14.4-windows-x86_64-none/python.exe -m pip install ipykernel -U --user --force-reinstall'
